# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# %%
# Examine Data
student_data.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
school_data.head()
# Out:
#    School ID            school_name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
# examine dtypes of merged data
school_data_complete.dtypes
# Out:
# Student ID        int64
# student_name     object
# gender           object
# grade            object
# school_name      object
# reading_score     int64
# math_score        int64
# School ID         int64
# type             object
# size              int64
# budget            int64
# dtype: object

# %%
# total schools
total_schools = school_data['school_name'].count()
total_schools
# Out:
# 15

# %%
# total students
total_students = school_data_complete["Student ID"].count() 
total_students
# Out:
# 39170

# %%
# total budget
total_budget = school_data["budget"].sum()
total_budget
# Out:
# 24649428

# %%
# total students
total_students = school_data_complete["Student ID"].count()
total_students
# Out:
# 39170

# %%
# calculate average math score
avg_math = student_data["math_score"].mean()
avg_math
# Out:
# 78.98537145774827

# %%
# calculate average reading score
avg_reading = student_data["reading_score"].mean()
avg_reading
# Out:
# 81.87784018381414

# %%
# establish 'math' dimensions and calculate passing math percentage
math = student_data["math_score"]
math_pass_df = student_data.loc[student_data["math_score"] >= 70]
math_pass_count = len(math_pass_df)
math_pass_percent = math_pass_count/total_students * 100
math_pass_percent
# Out:
# 74.9808526933878

# %%
# establish 'reading' dimensions and calculate passing reading percentage
reading = student_data["reading_score"]
reading_pass_df = student_data.loc[student_data["reading_score"] >= 70]
reading_pass_count = len(reading_pass_df)
reading_pass_percent = reading_pass_count/total_students * 100
reading_pass_percent
# Out:
# 85.80546336482001

# %%
# calculate both passing
passing_both_count = len(reading_pass_df.loc[reading_pass_df["math_score"] >= 70])
passing_both_percent = passing_both_count/total_students * 100
passing_both_percent
# Out:
# 65.17232575950983

# %%
# create summary DF
district_summary_df = pd.DataFrame({
    "Total Schools": [total_schools],
    "Total Students": [total_students],
    "Total Budget": [total_budget],
    "Avg Math Score": [avg_math],
    "Avg Reading Score": [avg_reading],
    "Passing Math %": [math_pass_percent],
    "Passing Reading %": [reading_pass_percent],
    "Passing Reading & Math %": [passing_both_percent]
})

print("District Summary")
district_summary_df
# Out:
# District Summary
#    Total Schools  Total Students  Total Budget  Avg Math Score  \
# 0             15           39170      24649428       78.985371
#
#    Avg Reading Score  Passing Math %  Passing Reading %  \
# 0           81.87784       74.980853          85.805463
#
#    Passing Reading & Math %
# 0                 65.172326

# %%
# Format Base table for school summary 
school_summary_base = school_data.rename(
    columns={
        "school_name": "School Name",
        "type": "Type",
        "size": "Total Students",
        "budget": "Total Student Budget"
    })
del school_summary_base["School ID"]
# add Budget per Student to school_summary_base
school_summary_base["Budget per Student"] = school_summary_base["Total Student Budget"]/school_summary_base["Total Students"]

# %%
# merge school averages with school summary table
school_group = school_data_complete.groupby(["school_name"])
school_avgs = school_group.mean()
school_avgs

# add school_avgs
school_summary_base = pd.merge(school_summary_base, school_avgs, how="left", left_on=["School Name"], right_on=["school_name"])
# delete duplicate or unnessary columns
del school_summary_base["Student ID"]
del school_summary_base["School ID"]
del school_summary_base["size"]
del school_summary_base["budget"]

# %%
# rename columns
school_summary_base = school_summary_base.rename(
    columns={
        "reading_score": "Avg Reading Score",
        "math_score": "Avg Math Score"
    })
school_summary_base
# Out:
#               School Name      Type  Total Students  Total Student Budget  \
# 0       Huang High School  District            2917               1910635
# 1    Figueroa High School  District            2949               1884411
# 2     Shelton High School   Charter            1761               1056600
# 3   Hernandez High School  District            4635               3022020
# 4     Griffin High School   Charter            1468                917500
# 5      Wilson High School   Charter            2283               1319574
# 6     Cabrera High School   Charter            1858               1081356
# 7      Bailey High School  District            4976               3124928
# 8      Holden High School   Charter             427                248087
# 9        Pena High School   Charter             962                585858
# 10     Wright High School   Charter            1800               1049400
# 11  Rodriguez High School  District            3999               2547363
# ...

# %%
# Calculate passing math grouped by school
# get counts by school
reading_pass_group = reading_pass_df.groupby(["school_name"])
reading_pass_group_count = reading_pass_group.count()
# math_pass_group_count
school_summary_base = pd.merge(school_summary_base, reading_pass_group_count, how="left", left_on=["School Name"], right_on=["school_name"])
school_summary_base
# Out:
#               School Name      Type  Total Students  Total Student Budget  \
# 0       Huang High School  District            2917               1910635
# 1    Figueroa High School  District            2949               1884411
# 2     Shelton High School   Charter            1761               1056600
# 3   Hernandez High School  District            4635               3022020
# 4     Griffin High School   Charter            1468                917500
# 5      Wilson High School   Charter            2283               1319574
# 6     Cabrera High School   Charter            1858               1081356
# 7      Bailey High School  District            4976               3124928
# 8      Holden High School   Charter             427                248087
# 9        Pena High School   Charter             962                585858
# 10     Wright High School   Charter            1800               1049400
# 11  Rodriguez High School  District            3999               2547363
# ...

# %%
school_summary_base = school_summary_base.rename(
    columns={"Student ID":"passingreadingcount"})
# delete duplicate or unnessary columns
del school_summary_base["student_name"]
del school_summary_base["gender"]
del school_summary_base["grade"]
del school_summary_base["reading_score"]
del school_summary_base["math_score"]
# calculate percent passing math
school_summary_base['Passing Reading %'] = school_summary_base['passingreadingcount']/school_summary_base["Total Students"]*100
del school_summary_base["passingreadingcount"]
school_summary_base
# Out:
#               School Name      Type  Total Students  Total Student Budget  \
# 0       Huang High School  District            2917               1910635
# 1    Figueroa High School  District            2949               1884411
# 2     Shelton High School   Charter            1761               1056600
# 3   Hernandez High School  District            4635               3022020
# 4     Griffin High School   Charter            1468                917500
# 5      Wilson High School   Charter            2283               1319574
# 6     Cabrera High School   Charter            1858               1081356
# 7      Bailey High School  District            4976               3124928
# 8      Holden High School   Charter             427                248087
# 9        Pena High School   Charter             962                585858
# 10     Wright High School   Charter            1800               1049400
# 11  Rodriguez High School  District            3999               2547363
# ...

# %%
# Calculate passing math grouped by school
# get counts by school
math_pass_group = math_pass_df.groupby(["school_name"])
math_pass_group_count = math_pass_group.count()
# math_pass_group_count
school_summary_base = pd.merge(school_summary_base, math_pass_group_count, how="left", left_on=["School Name"], right_on=["school_name"])
school_summary_base
# Out:
#               School Name      Type  Total Students  Total Student Budget  \
# 0       Huang High School  District            2917               1910635
# 1    Figueroa High School  District            2949               1884411
# 2     Shelton High School   Charter            1761               1056600
# 3   Hernandez High School  District            4635               3022020
# 4     Griffin High School   Charter            1468                917500
# 5      Wilson High School   Charter            2283               1319574
# 6     Cabrera High School   Charter            1858               1081356
# 7      Bailey High School  District            4976               3124928
# 8      Holden High School   Charter             427                248087
# 9        Pena High School   Charter             962                585858
# 10     Wright High School   Charter            1800               1049400
# 11  Rodriguez High School  District            3999               2547363
# ...

# %%
school_summary_base = school_summary_base.rename(
    columns={"Student ID":"passingmathcount"})
# delete duplicate or unnessary columns
del school_summary_base["student_name"]
del school_summary_base["gender"]
del school_summary_base["grade"]
del school_summary_base["reading_score"]
del school_summary_base["math_score"]
# calculate percent passing math
school_summary_base['Passing Math %'] = school_summary_base['passingmathcount']/school_summary_base["Total Students"]*100
del school_summary_base["passingmathcount"]
school_summary_base
# Out:
#               School Name      Type  Total Students  Total Student Budget  \
# 0       Huang High School  District            2917               1910635
# 1    Figueroa High School  District            2949               1884411
# 2     Shelton High School   Charter            1761               1056600
# 3   Hernandez High School  District            4635               3022020
# 4     Griffin High School   Charter            1468                917500
# 5      Wilson High School   Charter            2283               1319574
# 6     Cabrera High School   Charter            1858               1081356
# 7      Bailey High School  District            4976               3124928
# 8      Holden High School   Charter             427                248087
# 9        Pena High School   Charter             962                585858
# 10     Wright High School   Charter            1800               1049400
# 11  Rodriguez High School  District            3999               2547363
# ...

# %%
# Calculate passing both counts by school
passing_both_group = school_data_complete.loc[school_data_complete["math_score"] >= 70]
passing_both_group = passing_both_group.loc[passing_both_group["reading_score"] >= 70]
passing_both_group = passing_both_group.groupby(["school_name"])
passing_both_group_count = passing_both_group.count()
passing_both_group_count
school_summary_base = pd.merge(school_summary_base, passing_both_group_count, how="left", left_on=["School Name"], right_on=["school_name"])
school_summary_base
# Out:
#               School Name      Type  Total Students  Total Student Budget  \
# 0       Huang High School  District            2917               1910635
# 1    Figueroa High School  District            2949               1884411
# 2     Shelton High School   Charter            1761               1056600
# 3   Hernandez High School  District            4635               3022020
# 4     Griffin High School   Charter            1468                917500
# 5      Wilson High School   Charter            2283               1319574
# 6     Cabrera High School   Charter            1858               1081356
# 7      Bailey High School  District            4976               3124928
# 8      Holden High School   Charter             427                248087
# 9        Pena High School   Charter             962                585858
# 10     Wright High School   Charter            1800               1049400
# 11  Rodriguez High School  District            3999               2547363
# ...

# %%
school_summary_base = school_summary_base.rename(
    columns={"Student ID":"passingbothcount"})
# delete duplicate or unnessary columns
del school_summary_base["student_name"]
del school_summary_base["gender"]
del school_summary_base["grade"]
del school_summary_base["reading_score"]
del school_summary_base["math_score"]
del school_summary_base["School ID"]
del school_summary_base["size"]
del school_summary_base["budget"]

# calculate percent passing math
school_summary_base['Passing Both %'] = school_summary_base['passingbothcount']/school_summary_base["Total Students"]*100
del school_summary_base["passingbothcount"]
school_summary_base
# Out:
#               School Name      Type  Total Students  Total Student Budget  \
# 0       Huang High School  District            2917               1910635
# 1    Figueroa High School  District            2949               1884411
# 2     Shelton High School   Charter            1761               1056600
# 3   Hernandez High School  District            4635               3022020
# 4     Griffin High School   Charter            1468                917500
# 5      Wilson High School   Charter            2283               1319574
# 6     Cabrera High School   Charter            1858               1081356
# 7      Bailey High School  District            4976               3124928
# 8      Holden High School   Charter             427                248087
# 9        Pena High School   Charter             962                585858
# 10     Wright High School   Charter            1800               1049400
# 11  Rodriguez High School  District            3999               2547363
# ...

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * school_summary_baseool Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type
